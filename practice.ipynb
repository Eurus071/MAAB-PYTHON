# %% [markdown]
# ### Lesson 13

# %%
# %pip install numpy

# %%
import numpy as np

# %%
a=np.array([1, 2, 3])
a
# Out:
# array([1, 2, 3])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### Matplotlib

# %%
# %pip install matplotlib
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: matplotlib in c:\users\user\anaconda3\envs\rp_env\lib\site-packages (3.10.8)
# ...

# %%
import matplotlib.pyplot as plt
plt.__version__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.__version__
#
# AttributeError: module 'matplotlib.pyplot' has no attribute '__version__'

# %%
import matplotlib.pyplot as plt

x=[1, 2, 3, 4]
y=[10, 30, 20, 40]

plt.plot(x, y)
plt.show()

# %%
import numpy as np
a=np.arange(50)
b=np.random.randint(0, 50, 50)
sizes=np.abs(np.random.randn(50))*100

plt.scatter(a, b, s=sizes, c=b)
plt.colorbar()
plt.show()

# %%
categories=['red', 'blue', 'green', 'yellow']
values=[10, 15, 7, 12]

plt.barh(categories, values, color=[c.lower() for c in categories])
plt.title("Basic bar chart")
plt.xlabel("categories")
plt.ylabel("values")
plt.show()

# %%
categories=['A', 'B', 'C', 'D']
values1=[10, 15, 7, 12]
values2= [12, 18, 10, 15]

x=np.arange(len(categories))

w=0.4
plt.bar(x-w/2, values1, width=w, label='Dataset 1', color='blue')
plt.bar(x+w/2, values2, width=w, label='Dataset 2', color='green')

#plt.xticks(x, categories)
plt.title("Grouped Bar Chart")
plt.xlabel("Categories")
plt.ylabel("values")
plt.legend()
plt.show()

# %%
data=np.random.randn(1000)
data[:100]
# Out:
# array([-0.6248933 , -0.22029883,  0.66243802,  0.36978434, -0.50937984,
#         0.76456672, -1.03454665,  0.22043732,  0.21384613, -0.57705447,
#         0.39353903,  0.05234026,  0.83588606, -0.75607035,  1.7107412 ,
#        -0.69883117,  0.518342  ,  0.52822905,  0.50614673,  1.14164512,
#        -0.230426  , -0.41875995, -0.06943611, -0.72558875,  1.82171617,
#         1.70068593,  0.78053466,  0.3180756 , -1.2856394 ,  0.47383553,
#        -0.97434234,  1.53428845, -0.79960582,  0.64770761, -1.35754401,
#         1.40415075, -1.91616399,  0.51311407,  0.13607254,  2.10388711,
#        -2.23496916,  0.3571399 , -1.75843458,  0.06207939, -0.3712727 ,
#        -0.80755966,  0.1818427 ,  1.00755817, -2.49439602, -1.19555763,
#         0.36064161,  1.1222132 , -0.08488437,  0.01642605, -0.37050182,
#         0.8104537 ,  0.26676374,  1.77355623, -1.09197634, -2.29503723,
#        -1.04127563,  1.05199843,  0.89182637,  1.35136621, -0.97538951,
# ...

# %%
plt.hist(data, bins=20, color='skyblue', edgecolor='black')
plt.title('Basic Histogram')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Pandas

# %%
import csv
with open("data/employee.csv") as f:
    reader=csv.reader(f)
    print(next(reader))
    data=list(reader)
    print(data)
# Out:
# ['UNIQUE_ID', 'POSITION_TITLE', 'DEPARTMENT', 'BASE_SALARY', 'RACE', 'EMPLOYMENT_TYPE', 'GENDER', 'EMPLOYMENT_STATUS', 'HIRE_DATE', 'JOB_DATE']
# ...

# %%
data
# Out:
# [['0',
#   'ASSISTANT DIRECTOR (EX LVL)',
#   'Municipal Courts Department',
#   '121862.0',
#   'Hispanic/Latino',
#   'Full Time',
#   'Female',
#   'Active',
#   '2006-06-12',
#   '2012-10-13'],
#  ['1',
#   'LIBRARY ASSISTANT',
#   'Library',
#   '26125.0',
#   'Hispanic/Latino',
#   'Full Time',
#   'Female',
#   'Active',
#   '2000-07-19',
#   '2010-09-18'],
#  ['2',
#   'POLICE OFFICER',
#   'Houston Police Department-HPD',
#   '45279.0',
#   'White',
#   'Full Time',
#   'Male',
#   'Active',
#   '2015-02-03',
#   '2015-02-03'],
#  ['3',
#   'ENGINEER/OPERATOR',
#   'Houston Fire Department (HFD)',
#   '63166.0',
#   'White',
#   'Full Time',
#   'Male',
#   'Active',
#   '1982-02-08',
#   '1991-05-25'],
#  ['4',
#   'ELECTRICIAN',
#   'General Services Department',
#   '56347.0',
#   'White',
#   'Full Time',
#   'Male',
#   'Active',
#   '1989-06-19',
#   '1994-10-22'],
#  ['5',
#   'SENIOR POLICE OFFICER',
#   'Houston Police Department-HPD',
#   '66614.0',
# ...

# %%
gender=[row[6] for row in data]

# %%
from collections import Counter

nums=Counter(gender)
nums
# Out:
# Counter({'Male': 1397, 'Female': 603})

# %% [markdown]
# ### Series
# ### DataFrame

# %%
# %pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 381.6 kB/s eta 0:00:25
#    -- ------------------------------------- 0.5/9.9 MB 381.6 kB/s eta 0:00:25
#    --- ------------------------------------ 0.8/9.9 MB 453.5 kB/s eta 0:00:21
#    --- ------------------------------------ 0.8/9.9 MB 453.5 kB/s eta 0:00:21
#    --- ------------------------------------ 0.8/9.9 MB 453.5 kB/s eta 0:00:21
#    --- ------------------------------------ 0.8/9.9 MB 453.5 kB/s eta 0:00:21
# ...

# %% [markdown]
# CSV

# %%
import pandas as pd

df=pd.read_csv('data/employee.csv')
type(df)
# Out:
# pandas.DataFrame

# %%
df
# Out:
#       UNIQUE_ID               POSITION_TITLE                     DEPARTMENT  \
# 0             0  ASSISTANT DIRECTOR (EX LVL)    Municipal Courts Department
# 1             1            LIBRARY ASSISTANT                        Library
# 2             2               POLICE OFFICER  Houston Police Department-HPD
# 3             3            ENGINEER/OPERATOR  Houston Fire Department (HFD)
# 4             4                  ELECTRICIAN    General Services Department
# ...         ...                          ...                            ...
# 1995       1995               POLICE OFFICER  Houston Police Department-HPD
# 1996       1996       COMMUNICATIONS CAPTAIN  Houston Fire Department (HFD)
# 1997       1997               POLICE OFFICER  Houston Police Department-HPD
# 1998       1998               POLICE OFFICER  Houston Police Department-HPD
# 1999       1999                 FIRE FIGHTER  Houston Fire Department (HFD)
#
# ...

# %% [markdown]
# JSON

# %%
df_iris=pd.read_json('data/iris.json')
df_iris.head()
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa
# 2          4.7         3.2          1.3         0.2  setosa
# 3          4.6         3.1          1.5         0.2  setosa
# 4          5.0         3.6          1.4         0.2  setosa

# %% [markdown]
# EXCEL

# %%
df_titanic=pd.read_excel('data/titanic.xlsx', sheet_name='Sheet1')
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# %pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Html

# %%
# %pip install lxml
# Out:
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
# ...

# %%
df_countries_list=pd.read_html('https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_area')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df_countries_list=pd.read_html('https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_area')
#
# File c:\Users\user\anaconda3\envs\RP_env\Lib\site-packages\pandas\io\html.py:1226, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1222 check_dtype_backend(dtype_backend)
#    1224 io = stringify_path(io)
# -> 1226 return _parse(
#    1227     flavor=flavor,
#    1228     io=io,
#    1229     match=match,
#    1230     header=header,
#    1231     index_col=index_col,
#    1232     skiprows=skiprows,
#    1233     parse_dates=parse_dates,
#    1234     thousands=thousands,
#    1235     attrs=attrs,
# ...

# %% [markdown]
# Parquet

# %%
# %pip install pyarrow
# %pip install fastparquet
# Out:
# ...
#    ---------------------------------------- 0.0/27.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/27.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/27.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/27.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/27.5 MB ? eta -:--:--
#     --------------------------------------- 0.5/27.5 MB 599.9 kB/s eta 0:00:46
#    - -------------------------------------- 0.8/27.5 MB 714.3 kB/s eta 0:00:38
#    - -------------------------------------- 0.8/27.5 MB 714.3 kB/s eta 0:00:38
#    - -------------------------------------- 1.0/27.5 MB 762.8 kB/s eta 0:00:35
#    - -------------------------------------- 1.3/27.5 MB 745.8 kB/s eta 0:00:36
#    - -------------------------------------- 1.3/27.5 MB 745.8 kB/s eta 0:00:36
#    -- ------------------------------------- 1.6/27.5 MB 742.2 kB/s eta 0:00:35
# ...

# %% [markdown]
# Sqlite

# %%
import sqlite3

with sqlite3.connect('data/chinook.db') as connection:
    df_employee=pd.read_sql(
        "SELECT * FROM employees",
        con=connection
    )

# %%
df_employee.head(3)
# Out:
#    EmployeeId LastName FirstName                Title  ReportsTo  \
# 0           1    Adams    Andrew      General Manager        NaN
# 1           2  Edwards     Nancy        Sales Manager        1.0
# 2           3  Peacock      Jane  Sales Support Agent        2.0
#
#              BirthDate             HireDate              Address      City  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00  11120 Jasper Ave NW  Edmonton
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00         825 8 Ave SW   Calgary
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00        1111 6 Ave SW   Calgary
#
#   State Country PostalCode              Phone                Fax  \
# 0    AB  Canada    T5K 2N1  +1 (780) 428-9482  +1 (780) 428-3457
# 1    AB  Canada    T2P 2T3  +1 (403) 262-3443  +1 (403) 262-3322
# 2    AB  Canada    T2P 5M5  +1 (403) 262-3443  +1 (403) 262-6712
#
#                     Email
# 0  andrew@chinookcorp.com
# 1   nancy@chinookcorp.com
# 2    jane@chinookcorp.com

# %% [markdown]
# SQL Server

# %%
# %pip install pyodbc
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install SQLAlchemy
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.1 MB 558.9 kB/s eta 0:00:03
#    --------- ------------------------------ 0.5/2.1 MB 558.9 kB/s eta 0:00:03
#    -------------- ------------------------- 0.8/2.1 MB 568.6 kB/s eta 0:00:03
#    -------------- ------------------------- 0.8/2.1 MB 568.6 kB/s eta 0:00:03
#    -------------- ------------------------- 0.8/2.1 MB 568.6 kB/s eta 0:00:03
#    -------------- ------------------------- 0.8/2.1 MB 568.6 kB/s eta 0:00:03
#    ------------------- -------------------- 1.0/2.1 MB 453.3 kB/s eta 0:00:03
#    ------------------- -------------------- 1.0/2.1 MB 453.3 kB/s eta 0:00:03
# ...

# %%
from sqlalchemy import create_engine

SERVER_NAME='localhost/SQL2022'
DATABASE_NAME='finalexam'
DRIVER='ODBC+Driver+17+for+SQL+Server'
CONNECTION_STRING=f'mssql+pyodbc://{SERVER_NAME}/{DATABASE_NAME}?trusted_connection=yes&driver={DRIVER}'
print(CONNECTION_STRING)
# Out:
# mssql+pyodbc://localhost/SQL2022/finalexam?trusted_connection=yes&driver=ODBC+Driver+17+for+SQL+Server

# %%
ms_sql_engine=create_engine(CONNECTION_STRING)

# %%
db_employee=pd.read_sql(
    "select * from zillow_transactions",
    con=ms_sql_engine
)
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# File c:\Users\user\anaconda3\envs\RP_env\Lib\site-packages\sqlalchemy\engine\base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 try:
# --> 143     self._dbapi_connection = engine.raw_connection()
#     144 except dialect.loaded_dbapi.Error as err:
#
# File c:\Users\user\anaconda3\envs\RP_env\Lib\site-packages\sqlalchemy\engine\base.py:3309, in Engine.raw_connection(self)
#    3288 """Return a "raw" DBAPI connection from the connection pool.
#    3289
#    3290 The returned object is a proxied version of the DBAPI
#    (...)
#    3307
#    3308 """
# -> 3309 return self.pool.connect()
#
# File c:\Users\user\anaconda3\envs\RP_env\Lib\site-packages\sqlalchemy\pool\base.py:447, in Pool.connect(self)
#     440 """Return a DBAPI connection from the pool.
#     441
# ...

# %% [markdown]
# Convert from list and dict

# %%
data=[
    ['John', 'Doe', 40],
    ['John', 'Doe', 44],
    ['Adam', 'Smith', 40]
]
columns=['FirstName', 'Lastname', 'Age']

df=pd.DataFrame(data=data, columns=columns)
df
# Out:
#   FirstName Lastname  Age
# 0      John      Doe   40
# 1      John      Doe   44
# 2      Adam    Smith   40

# %% [markdown]
# Pandas working

# %%
df_iris.head()
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa
# 2          4.7         3.2          1.3         0.2  setosa
# 3          4.6         3.1          1.5         0.2  setosa
# 4          5.0         3.6          1.4         0.2  setosa

# %%
df_iris.tail()
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica

# %%
df_iris.sample()
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 107          7.3         2.9          6.3         1.8  virginica

# %%
df_iris.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sepalLength  150 non-null    float64
#  1   sepalWidth   150 non-null    float64
#  2   petalLength  150 non-null    float64
#  3   petalWidth   150 non-null    float64
#  4   species      150 non-null    str
# dtypes: float64(4), str(1)
# memory usage: 6.0 KB

# %%
df_iris.describe()
# Out:
#        sepalLength  sepalWidth  petalLength  petalWidth
# count   150.000000  150.000000   150.000000  150.000000
# mean      5.843333    3.057333     3.758000    1.199333
# std       0.828066    0.435866     1.765298    0.762238
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.350000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %%
len(df_iris)
# Out:
# 150

# %%
df_employee.shape
# Out:
# (8, 15)

# %%
df_employee.dtypes
# Out:
# employeeid      int64
# lastname          str
# firstname         str
# title             str
# reportsto     float64
# birthdate         str
# hiredate          str
# address           str
# city              str
# state             str
# country           str
# postalcode        str
# phone             str
# fax               str
# email             str
# dtype: object

# %%
df_employee.columns
# Out:
# Index(['employeeid', 'lastname', 'firstname', 'title', 'reportsto',
#        'birthdate', 'hiredate', 'address', 'city', 'state', 'country',
#        'postalcode', 'phone', 'fax', 'email'],
#       dtype='str')

# %%
new_columns=[column.lower() for column in df_employee.columns]
new_columns
# Out:
# ['employeeid',
#  'lastname',
#  'firstname',
#  'title',
#  'reportsto',
#  'birthdate',
#  'hiredate',
#  'address',
#  'city',
#  'state',
#  'country',
#  'postalcode',
#  'phone',
#  'fax',
#  'email']

# %%
df_employee.columns=new_columns

# %%
df_employee.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
#df=pd.read_csv('data/employee.csv', index_col='Employeeid')
#df.set_index('employeeid', inplace=True)
df_employee.columns
# Out:
# Index(['employeeid', 'lastname', 'firstname', 'title', 'reportsto',
#        'birthdate', 'hiredate', 'address', 'city', 'state', 'country',
#        'postalcode', 'phone', 'fax', 'email'],
#       dtype='str')

# %%
df_employee.head()
# Out:
#    employeeid lastname firstname                title  reportsto  \
# 0           1    Adams    Andrew      General Manager        NaN
# 1           2  Edwards     Nancy        Sales Manager        1.0
# 2           3  Peacock      Jane  Sales Support Agent        2.0
# 3           4     Park  Margaret  Sales Support Agent        2.0
# 4           5  Johnson     Steve  Sales Support Agent        2.0
#
#              birthdate             hiredate              address      city  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00  11120 Jasper Ave NW  Edmonton
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00         825 8 Ave SW   Calgary
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00        1111 6 Ave SW   Calgary
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00     683 10 Street SW   Calgary
# 4  1965-03-03 00:00:00  2003-10-17 00:00:00         7727B 41 Ave   Calgary
#
#   state country postalcode              phone                fax  \
# ...

# %%
df_iris['new_column']=['low' if 1<5.8 else 'high' for i in df_iris['sepalLength']]
df_iris.head()
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth species new_column
# 0          5.1         3.5          1.4         0.2  setosa        low
# 1          4.9         3.0          1.4         0.2  setosa        low
# 2          4.7         3.2          1.3         0.2  setosa        low
# 3          4.6         3.1          1.5         0.2  setosa        low
# 4          5.0         3.6          1.4         0.2  setosa        low

# %%
df_iris=df_iris.drop(columns=['new_column'])
df_iris
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %%
df_iris.sort_values(by=['sepalLength'])
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 13           4.3         3.0          1.1         0.1     setosa
# 8            4.4         2.9          1.4         0.2     setosa
# 42           4.4         3.2          1.3         0.2     setosa
# 38           4.4         3.0          1.3         0.2     setosa
# 41           4.5         2.3          1.3         0.3     setosa
# ..           ...         ...          ...         ...        ...
# 122          7.7         2.8          6.7         2.0  virginica
# 117          7.7         3.8          6.7         2.2  virginica
# 118          7.7         2.6          6.9         2.3  virginica
# 135          7.7         3.0          6.1         2.3  virginica
# 131          7.9         3.8          6.4         2.0  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Pandas

# %% [markdown]
# #### joining data frames

# %%
import pandas as pd

df1=pd.DataFrame(
    {
        'id': [1, 2, 3],
        'name': ['Alice', 'Bob', 'John']
    }
)
df2=pd.DataFrame(
    {
        'id': [4, 5, 6],
        'name': ['Jane', 'Adam', 'Josh']
    }
)
df1
df2
# Out:
#    id  name
# 0   4  Jane
# 1   5  Adam
# 2   6  Josh

# %%
pd.concat([df1, df2])
# Out:
#    id   name
# 0   1  Alice
# 1   2    Bob
# 2   3   John
# 0   4   Jane
# 1   5   Adam
# 2   6   Josh

# %% [markdown]
# ** defoult inner join **

# %%
result=pd.merge(df1, df2, on='id', suffixes=['_left', '_right'], how='outer')
result
# Out:
#    id name_left name_right
# 0   1     Alice        NaN
# 1   2       Bob        NaN
# 2   3      John        NaN
# 3   4       NaN       Jane
# 4   5       NaN       Adam
# 5   6       NaN       Josh

# %%
result.sort_values(by=['name_left'])
# Out:
#    id name_left name_right
# 0   1     Alice        NaN
# 1   2       Bob        NaN
# 2   3      John        NaN
# 3   4       NaN       Jane
# 4   5       NaN       Adam
# 5   6       NaN       Josh

# %%
res_temp=pd.merge(df1, df2, on='id', how='left')
res_temp
# Out:
#    id name_x name_y
# 0   1  Alice    NaN
# 1   2    Bob    NaN
# 2   3   John    NaN

# %%
res_temp[res_temp['name_x'].isna().drop(columns='id')]
# Out:
# Empty DataFrame
# Columns: [id, name_x, name_y]
# Index: []

# %% [markdown]
# ### Working with salary

# %%
import pandas as pd
df=pd.DataFrame(
    {
        'Department': ['Hr', 'Hr', 'IT', 'IT', 'Finance', 'Finance'],
        'Employee': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank'],
        'Salary': [50000, 60000, 70000, 80000, 90000, 100000]
    }
)
df
# Out:
#   Department Employee  Salary
# 0         Hr    Alice   50000
# 1         Hr      Bob   60000
# 2         IT  Charlie   70000
# 3         IT    David   80000
# 4    Finance      Eva   90000
# 5    Finance    Frank  100000

# %%
df['Salary'].max()
# Out:
# np.int64(100000)

# %%
unique_departments=df['Department'].drop_duplicates().tolist()
unique_departments
# Out:
# ['Hr', 'IT', 'Finance']

# %%
for department in unique_departments:
    filtered=df[df['Department']==department]
    #display(filtered)
    #print('-'*50)
    max_sal=filtered['Salary'].max()
    print(f'Max salary for the {department} is {max_sal}')
# Out:
# Max salary for the Hr is 60000
# Max salary for the IT is 80000
# Max salary for the Finance is 100000

# %%
result=df.groupby('Department')
type(result)
# Out:
# pandas.api.typing.DataFrameGroupBy

# %%
result.max()
# Out:
#            Employee  Salary
# Department
# Finance       Frank  100000
# Hr              Bob   60000
# IT            David   80000

# %%
max_df=df.groupby('Department')['Salary'].max()
min_df=df.groupby('Department')['Salary'].min()
pd.merge(max_df, min_df, left_index=True, right_index=True)
# Out:
#             Salary_x  Salary_y
# Department
# Finance       100000     90000
# Hr             60000     50000
# IT             80000     70000

# %%
df.groupby('Department')['Salary'].agg(['min', 'max', 'median']).reset_index()
# Out:
#   Department    min     max   median
# 0    Finance  90000  100000  95000.0
# 1         Hr  50000   60000  55000.0
# 2         IT  70000   80000  75000.0

# %%
def custom(x):
    return x.mean()

df.groupby('Department')['Salary'].agg(['min', custom])
# Out:
#               min   custom
# Department
# Finance     90000  95000.0
# Hr          50000  55000.0
# IT          70000  75000.0

# %%
df['Bonus']=2*df['Salary']

# %%
result=df.groupby('Department').agg(
    {
        'Salary': ['min', 'max', 'mean'],
        'Bonus': ['sum', 'mean']
    }
)
result
# Out:
#            Salary                    Bonus
#               min     max     mean     sum      mean
# Department
# Finance     90000  100000  95000.0  380000  190000.0
# Hr          50000   60000  55000.0  220000  110000.0
# IT          70000   80000  75000.0  300000  150000.0

# %%
result['Salary']['max']
# Out:
# Department
# Finance    100000
# Hr          60000
# IT          80000
# Name: max, dtype: int64

# %%
for i in result.columns:
    print(i[0]+'_'+i[1])
# Out:
# Salary_min
# Salary_max
# Salary_mean
# Bonus_sum
# Bonus_mean

# %%
['_'.join(col) for col in result.columns]
# Out:
# ['Salary_min', 'Salary_max', 'Salary_mean', 'Bonus_sum', 'Bonus_mean']

# %%
result.columns=['_'.join(col) for col in result.columns]

# %%
result
# Out:
#             Salary_min  Salary_max  Salary_mean  Bonus_sum  Bonus_mean
# Department
# Finance          90000      100000      95000.0     380000    190000.0
# Hr               50000       60000      55000.0     220000    110000.0
# IT               70000       80000      75000.0     300000    150000.0

# %%
def demo(x):
    print(type(x))

df['Salary'].apply(demo)
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# 5    None
# Name: Salary, dtype: object

# %%
df.apply(lambda x: x*2)
# Out:
#        Department        Employee  Salary   Bonus
# 0            HrHr      AliceAlice  100000  200000
# 1            HrHr          BobBob  120000  240000
# 2            ITIT  CharlieCharlie  140000  280000
# 3            ITIT      DavidDavid  160000  320000
# 4  FinanceFinance          EvaEva  180000  360000
# 5  FinanceFinance      FrankFrank  200000  400000

# %%
df.apply(demo, axis=1)
# Out:
# <class 'pandas.Series'>
# <class 'pandas.Series'>
# <class 'pandas.Series'>
# <class 'pandas.Series'>
# <class 'pandas.Series'>
# <class 'pandas.Series'>
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# 5    None
# dtype: object

# %%
def debug(x):
    display(x)
    print('-'*50)
    return x

df.apply(debug, axis=0)
# Out:
# 0         Hr
# 1         Hr
# 2         IT
# 3         IT
# 4    Finance
# 5    Finance
# Name: Department, dtype: str
# --------------------------------------------------
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4        Eva
# 5      Frank
# Name: Employee, dtype: str
# --------------------------------------------------
# 0     50000
# 1     60000
# 2     70000
# 3     80000
# 4     90000
# 5    100000
# Name: Salary, dtype: int64
# --------------------------------------------------
# 0    100000
# 1    120000
# 2    140000
# 3    160000
# 4    180000
# 5    200000
# Name: Bonus, dtype: int64
# --------------------------------------------------
#   Department Employee  Salary   Bonus
# 0         Hr    Alice   50000  100000
# 1         Hr      Bob   60000  120000
# 2         IT  Charlie   70000  140000
# 3         IT    David   80000  160000
# 4    Finance      Eva   90000  180000
# 5    Finance    Frank  100000  200000
# ...

# %%
import pandas as pd
# Sample DataFrame
data = {
   'Date': ['2023-01-01', '2023-01-01', '2023-01-02', '2023-01-02'],
   'City': ['New York', 'Los Angeles', 'New York', 'Los Angeles'],
   'Temperature': [32, 75, 30, 77]
}
df = pd.DataFrame(data)
# Create pivot table
pivot_df = pd.pivot_table(df, index='Date', columns='City', values='Temperature')
print(pivot_df)
# Out:
# City        Los Angeles  New York
# Date
# 2023-01-01         75.0      32.0
# 2023-01-02         77.0      30.0

# %%
df
# Out:
#          Date         City  Temperature
# 0  2023-01-01     New York           32
# 1  2023-01-01  Los Angeles           75
# 2  2023-01-02     New York           30
# 3  2023-01-02  Los Angeles           77

# %%
import pandas as pd
# Sample DataFrame
df = pd.DataFrame({
   'Name': ['John', 'Bob', 'Shiela'],
   'Course': ['Masters', 'Graduate', 'Graduate'],
   'Age': [27, 23, 21]
})
# Melt the DataFrame
melted_df = pd.melt(df, id_vars=['Name'], value_vars=['Course', 'Age'],
                   var_name='Attribute', value_name='Detail')
print(melted_df)
# Out:
#      Name Attribute    Detail
# 0    John    Course   Masters
# 1     Bob    Course  Graduate
# 2  Shiela    Course  Graduate
# 3    John       Age        27
# 4     Bob       Age        23
# 5  Shiela       Age        21

# %%
df
# Out:
#      Name    Course  Age
# 0    John   Masters   27
# 1     Bob  Graduate   23
# 2  Shiela  Graduate   21

# %%
number=int(input('enter: '))
result=[]
for i in range(number):
    result.append(i**2)

for j in range(len(result)-1):
    print(result[j])
# Out:
# 0
# 1
# 4
# 9

# %% [markdown]
# ## Final prep

# %% [markdown]
# Task:
# Shart: Book va Library classlarini yarating.
#
# Book class: title, author, va is_borrowed (default False) xususiyatlariga ega bo'lsin.
#
# Library class:
#
# books ro'yxati (bu yerda Book obyektlari saqlanadi).
#
# add_book(book) – yangi kitob qo'shish.
#
# borrow_book(title) – kitobni ijaraga berish. Agar kitob kutubxonada bo'lsa va ijaraga olinmagan bo'lsa, is_borrowed ni True ga o'zgartirsin. Aks holda "Kitob band" yoki "Mavjud emas" desin.
#
# return_book(title) – kitobni qaytarish.
#
# search_by_author(author) – berilgan muallifning barcha kitoblarini qaytarsin.

# %%
class Book():
    def __init__(self, title, author):
        self.title=title
        self.author=author
        self.is_borrowed=False

class Library():
    def __init__(self):
        self.books=[]

    def add_book(self, new_book):
        self.books.append(new_book)

    def borrow_book(self, borrowed):
        self.borrowed=True

        for book in self.book:
            if book.title==self.title:
                if not book.is_borrowed:
                    book.is_boorowed=True
                    print('Kitob ijaraga berildi')
                    return 
                else:
                    print('Kitob band')
                    return
        print('Kitob Mavjud emas')

    def return_book(self, title):
        for book in self.books:
            if book.title==title:
                if book.is_borrowed:
                    book.is_borrowed=False
                    print('Kitob qaytarildi')
                    return
        print('Kitob topilmadi')

    def search_by_author(self, author):
        result=[]
        for book in self.books:
            if book.author==author:
                result.appand[book.title]
        return result

# %% [markdown]
# Task:
# Berilgan sonlar ro‘yxati nums.
# Har bir element nechta marta uchrashganini hisoblab, natijani dict ko‘rinishida chiqaring.
#
# Misol:
# Input: [1,2,2,3,3,3]
# Output:
# {1:1, 2:2, 3:3}

# %%
nums=[1, 2, 2, 3, 3, 3]
count_dic={}

for num in nums:
    if num in count_dic:
        count_dic[num]+=1
    else:
        count_dic[num]=1
print(count_dic)
# Out:
# {1: 1, 2: 2, 3: 3}

# %% [markdown]
# Task:
# Berilgan songacha tub (prime) sonlarni hosil qiladigan Python dasturini yozing.
#
# Dasturingiz quyidagilarni bajarishi kerak:
#
# Foydalanuvchidan yuqori chegara sifatida musbat butun son kiritishni so‘rang.
#
# Kiritilgan chegaragacha bo‘lgan barcha tub sonlarni topish algoritmini amalga oshiring.
#
# Topilgan tub sonlar ro‘yxatini ekranga chiqaring.
#
# Masalan, agar foydalanuvchi chegara sifatida 20 ni kiritsa, dastur 20 ga teng yoki undan kichik tub sonlarni chiqarishi kerak:
# [2, 3, 5, 7, 11, 13, 17, 19].

# %%
edge=int(input('Enter the edge number: '))
prime_nums=[]
for i in range(2, edge+1):
    is_prime=False

    for j in range(2, int(num**0.5)+1):
        if i%j==0:
           is_prime
           break


    if not is_prime:
        prime_nums.append(i)

print(prime_nums)
# Out:
# [2, 3, 4, 5, 6, 7]

# %% [markdown]
# Task:
# Foydalanuvchidan matn (string) kiritishni so‘raydigan va so‘ngra shu matnning teskari (reverse) ko‘rinishini chiqaradigan Python dasturini yozing.
#
# Masalan, agar foydalanuvchi "Hello, World!" deb kiritsa, dastur  "!dlroW ,olleH" natijasini chiqarishi kerak.

# %%
#1st

str=input("Enter the string you want: ")
print(str[::-1])
# Out:
# fjks

# %%
#2nd
str=input('Enter the string you want: ')

reverse=''

for char in str:
    reverse=char+reverse
print(reverse)
# Out:
# nfwejk

# %% [markdown]
# Foydalanuvchi son kiritadi.
# Agar:
#
# 3 ga bo‘linsa → "Fizz"
#
# 5 ga bo‘linsa → "Buzz"
#
# 3 va 5 ga ham bo‘linsa → "FizzBuzz"
#
# aks holda sonni o‘zi chiqsin

# %%
number=int(input('Enter the number: '))

if number%3==0 and number%5==0:
    print('PizzBuzz')
elif number%3==0:
    print('Fizz')
elif number%5==0:
    print('Buzz')
else:
    print('number')

# %% [markdown]
# Berilgan matndan faqat unli harflarni ajratib yangi string hosil qiling.

# %%
text=input('Enter the string: ')
vowels='aeiou'
result=''
for char in text:
    if char.lower() in vowels:
        result=char+result
print(result)
# Out:
# E

# %% [markdown]
# Berilgan list ichida eng ko‘p uchragan elementni toping.

# %%
from collections import Counter
numbers=[1, 2, 2, 2, 2,  3, 3, 3]
disc=Counter(numbers)
max_list=[]
for key in disc:
    max_list.append[disc[key]]
print(max(max_list))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 4
#       2 numbers=[1, 2, 2, 2, 2,  3, 3, 3]
#       3 disc=Counter(numbers)
# ----> 4 max_val=max(disc[key])
#       5 max_val
#
# NameError: name 'key' is not defined

# %% [markdown]
# Class yarating:
#
# Student class:
#
# name
#
# grades (list)
#
# Method:
#
# add_grade()
#
# average()
#
# is_passed() → agar average ≥ 60 bo‘lsa True qaytarsin

# %%
class Student():
    def __init__self(self, name):
        self.name=name
        self.grades=[]
    def add_grade(grade):
        self.grades.append(grade)
    def average(grade):
        average=True

    def is_passed(grade):
        if grade>=60:
            self.average.average
        return

# %% [markdown]
# Given a number n.
# Print:
#
# "Positive Even"
#
# "Positive Odd"
#
# "Negative"
#
# "Zero"
#
# Correct classification required.

# %%
n=int(input('Enter the number: '))
if n==0:
    print("Zero")
elif n<0:
    print("Negative")
elif n>0 and n%2==0:
    print("Positive even")
else:
    print('Positive odd')
# Out:
# Positive odd

# %%
text=input('Enter the text u want: ')
txt=text.strip()
dict={'vowels': 0, 'consonants': 0, 'digits': 0}
vowels='aeiou'
consonants='qwrtypsdfghjklmnbvcxz'
for char in txt:
    if char.lower() in vowels:
        dict['vowels']+=1
    elif char.lower() in consonants:
        dict['consonants']+=1
    elif char.isdigit():
        dict['digits']+=1
print(dict)
# Out:
# {'vowels': 3, 'consonants': 11, 'digits': 6}

# %% [markdown]
# Given a list of numbers, return second largest number
# WITHOUT using sort().

# %%
numbers=[4, 8, 1, 9, 3]
sorted_numbers=numbers.sort()
print(sorted_numbers[-2])

# %% [markdown]
# Write a function that checks if a string is palindrome
# (ignoring spaces and case).

# %%
def palindrome(text):
    txt=text.strip()
    if txt==txt[::-1]:
       return True
    else:
        return False

text=input('Enteryour string: ')
palindrome(text)
# Out:
# 'Not palindrome'

# %% [markdown]
# Create class BankAccount:
#
# Attributes:
#
# owner
#
# balance (default 0)
#
# Methods:
#
# deposit(amount)
#
# withdraw(amount) (if insufficient → print "Insufficient funds")
#
# display_balance()

# %%
class BankAccount():
    def __init__(self, owner):
        self.owner=owner
        self.balance=0
    def deposit(self, amount):
        self.sufficient=False
        if self.amount==0:
            self.sufficient
        return self.amount

    def withdraw(self, amount):
        if self.deposit.sufficient:
            print('Insufficient funds')
        else:

    def display_balance(self):
